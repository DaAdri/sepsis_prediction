# %%
import hl7apy
from hl7apy import parser
from hl7apy.core import Group, Segment
from hl7apy.exceptions import UnsupportedVersion

# Chemins vers les fichiers HL7
file_paths = [
    r"D:\stage\data\DataMai2024\DataMai2024\archive(6)\EXEMPLE1_GLIMS_HL7_RESULTATS\EXEMPLE1_GLIMS_HL7_RESULTATS\2404161450-0001.txt",
    r"D:\stage\data\DataMai2024\DataMai2024\archive(6)\EXEMPLE1_GLIMS_HL7_RESULTATS\EXEMPLE1_GLIMS_HL7_RESULTATS\2404161450-0002.txt",
    r"D:\stage\data\DataMai2024\DataMai2024\archive(6)\EXEMPLE1_GLIMS_HL7_RESULTATS\EXEMPLE1_GLIMS_HL7_RESULTATS\2404161510-0001.txt",
    r"D:\stage\data\DataMai2024\DataMai2024\archive(6)\EXEMPLE1_GLIMS_HL7_RESULTATS\EXEMPLE1_GLIMS_HL7_RESULTATS\2404161515-0001.txt"
]

messages = []

# Lecture et analyse des fichiers HL7
for file_path in file_paths:
    with open(file_path, "r") as file:
        hl7 = file.read()
    try:
        msg = parser.parse_message(hl7.replace('\n', '\r'), find_groups=True, validation_level=2)
    except UnsupportedVersion:
        print(f'Unsupported version in file: {file_path}')
        msg = parser.parse_message(hl7.replace('\n', '\r'), find_groups=True, validation_level=2)
    messages.append(msg)

# Fonction pour afficher les sous-groupes de manière récursive
def subgroup(group, indent):
    indent = indent + "    "
    print(indent, group)
    for group_segment in group.children:
        if isinstance(group_segment, Group):
            subgroup(group_segment, indent)
        else:
            print(indent_seg, indent, group_segment)
            for attribute in group_segment.children:
                print(indent_fld, indent, attribute, attribute.value)

# Fonction pour afficher les messages HL7
def showmsg(msg):
    for segment in msg.children:
        if isinstance(segment, Segment):
            print(indent, segment)
            for attribute in segment.children:
                print(indent_fld, indent, attribute, attribute.value)
        elif isinstance(segment, Group):
            print(indent, segment)
            for group_segment in segment.children:
                if isinstance(group_segment, Group):
                    subgroup(group_segment, indent)
                else:
                    print(indent_seg, indent, group_segment)
                    for attribute in group_segment.children:
                        print(indent_fld, indent, attribute, attribute.value)

# Indentations pour l'affichage
indent = "    "
indent_seg = "    "
indent_fld = "        "

# Affichage des messages HL7 analysés
for i, msg in enumerate(messages, start=1):
    print(f"\nMessage {i}:")
    showmsg(msg)
# Out:
# Message 1:
#      <Segment MSH>
#               <Field MSH_1 (FIELD_SEPARATOR) of type ST> |
#               <Field MSH_2 (ENCODING_CHARACTERS) of type ST> ^~\&
#               <Field MSH_3 (SENDING_APPLICATION) of type ST> GLIMS
#               <Field MSH_4 (SENDING_FACILITY) of type ST> carevue_hl7
#               <Field MSH_5 (RECEIVING_APPLICATION) of type ST> 4041
#               <Field MSH_6 (RECEIVING_FACILITY) of type ST> carevue_hl7
#               <Field MSH_7 (DATE_TIME_OF_MESSAGE) of type TS> 20240416145007
#               <Field MSH_9 (MESSAGE_TYPE) of type CM_MSG> ORU^R01
#               <Field MSH_10 (MESSAGE_CONTROL_ID) of type ST> 47508
#               <Field MSH_11 (PROCESSING_ID) of type ID> P
#               <Field MSH_12 (VERSION_ID) of type NM> 2.1
#               <Field of type None> AL
#               <Field of type None> NE
#      <Group ORU_R01_PATIENT_RESULT>
#          <Group ORU_R01_PATIENT>
#               <Segment PID>
# ...

# %%
print(messages[2].ORU_R01_PATIENT_RESULT.ORU_R01_ORDER_OBSERVATION.children)
# Out:
# [<Segment OBR>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>, <Group ORU_R01_OBSERVATION>]

# %%
msg = messages[2]

# %%
from hl7apy.core import Group, Segment
print(msg.children[0])
# Out:
# <Segment MSH>

# %%
#import hl7apy.core
print(type(msg.msh.children[0]))
# Out:
# <class 'hl7apy.core.Field'>

# %%
import hl7apy.core
print(msg.msh.Field('msh_1'))
# Out:
# ---------------------------------------------------------------------------
# ChildNotFound                             Traceback (most recent call last)
# Cell In[28], line 2
#       1 import hl7apy.core
# ----> 2 print(msg.msh.Field('msh_1'))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\hl7apy\core.py:165, in ElementProxy.__getattr__(self, name)
#     163     except IndexError:
#     164         element = self.element_list.create_element(self.element_name, traversal_parent=True)
# --> 165 return getattr(element, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\hl7apy\core.py:846, in Element.__getattr__(self, name)
#     844 def __getattr__(self, name):
#     845     if hasattr(self, 'children') and name not in self.cls_attrs:
# --> 846         return self.children.get(name)
#     847     else:
#     848         raise AttributeError(name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\hl7apy\core.py:287, in ElementList.get(self, name)
# ...

# %%
print(msg.msh.FIELD_SEPARATOR.value)
# Out:
# |
